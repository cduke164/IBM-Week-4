# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Carmen Duke**
#
# Healthcare Data Analyst

# %% [markdown]
# *I am interested in data science because I believe data can be used to make healthcare (and the world!) a better place*

# %% [markdown]
# #### My code will compute 16 divided by 2

# %%
16/2
# Out:
# 8.0

# %% [markdown]
# 1. Milk
# 1. Eggs
# 1. Bread
#
# * Milk
# * Eggs
# * Bread
#
# __[Google](https://www.google.com/)__
